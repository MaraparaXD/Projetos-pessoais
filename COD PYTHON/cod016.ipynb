# %%
cadastro = {
    'matricula': 1015,
    'dia_cadastro': 26, 
    'mes_cadastro': 10,
    'turma': '2E'
}
cadastro
# Out:
# {'matricula': 1015, 'dia_cadastro': 26, 'mes_cadastro': 10, 'turma': '2E'}

# %%
cadastro['matricula']
# Out:
# 1015

# %%
cadastro['turma']
# Out:
# '2E'

# %%
cadastro['turma'] = '2G'
cadastro['turma']
# Out:
# '2G'

# %%
cadastro['modalidade'] = 'ead'
cadastro['modalidade']
# Out:
# 'ead'

# %%
cadastro
# Out:
# {'matricula': 1015,
#  'dia_cadastro': 26,
#  'mes_cadastro': 10,
#  'turma': '2G',
#  'modalidade': 'ead'}

# %%
cadastro.items()
# Out:
# dict_items([('matricula', 1015), ('dia_cadastro', 26), ('mes_cadastro', 10), ('turma', '2G'), ('modalidade', 'ead')])

# %%
cadastro.keys()
# Out:
# dict_keys(['matricula', 'dia_cadastro', 'mes_cadastro', 'turma', 'modalidade'])

# %%
cadastro.values()
# Out:
# dict_values([1015, 26, 10, '2G', 'ead'])

# %%
for chaves in cadastro.keys():
    print(cadastro[chaves])
# Out:
# 1015
# 26
# 10
# 2G
# ead

# %%
for valores in cadastro.values():
    print(valores)
# Out:
# 1015
# 26
# 10
# 2G
# ead

# %%
for chaves, valores in cadastro.items():
    print(chaves, valores)
# Out:
# matricula 1015
# dia_cadastro 26
# mes_cadastro 10
# turma 2G
# modalidade ead
