# %%
loja = {
    'Produto':['Celular A27', 'Notebook Acer Aspire Nitro 5','Monitor Gamming 144h', 'PC I5'],
    'Preço':[1200,4500, 800, 2220]
}

# %%
for chave, elementos in loja.items():
    print(f'Chave: {chave}\nElementos:')
    for dado in elementos:
        print(dado)
# Out:
# Chave: Produto
# Elementos:
# Celular A27
# Notebook Acer Aspire Nitro 5
# Monitor Gamming 144h
# PC I5
# Chave: Preço
# Elementos:
# 1200
# 4500
# 800
# 2220
