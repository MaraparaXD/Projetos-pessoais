# %%
lista = ['Tiago', 10, 9, 8, True]
len(lista)
# Out:
# 5

# %%
lista[1:4]
# Out:
# [10, 9, 8]

# %%
lista[:3]
# Out:
# ['Tiago', 10, 9]

# %%
lista[2:3]
# Out:
# [9]

# %%
lista[:]
# Out:
# ['Tiago', 10, 9, 8, True]

# %%
lista.append('media')

# %%
lista.extend([10.0, 6.0, 8.0])

# %%
lista.append([10.0,8.0,9.0])
lista
# Out:
# ['Tiago', 10, 9, 8, True, 'media', 10.0, 6.0, 8.0, [10.0, 8.0, 9.0]]

# %%
lista.remove([10.0,8.0,9.0])
lista
# Out:
# ['Tiago', 10, 9, 8, True, 'media', 10.0, 6.0, 8.0]
